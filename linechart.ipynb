# %% [markdown]
# # Line chart in matplotlic-python
# syntax = plt.plot(x,y,color,linestyle,linewidth,marker)

# %%
import numpy as np 
import matplotlib.pyplot as plt 
days = ["Monday","Tuesday","WednesdaY","Thursday","Friday","Saturtday"]
temprature = [22,24,24,26,25,21]
plt.plot(days,temprature,marker="o",label="y=2x")
plt.title("Weekly Temprature")
plt.xlabel("Days")
plt.ylabel("Temprature (c)")
plt.grid(True)
plt.legend()
plt.show()

# %%
x=[1,3,4,6,5,3,4,5,6,4,3]
y=[8,6,7,4,6,5,3,4,5,3,4]
a=np.arange(10)
plt.plot(x,y,color="green",alpha=0.4,linestyle="-.")

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.plot(x, y_sin, label="sin(x)")
plt.plot(x, y_cos, label="cos(x)")
plt.xlabel("X values")
plt.ylabel("Function value")
plt.title("Trigonometric Functions")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
sales = [400, 350, 300, 450]

plt.bar(fruits, sales, color='violet')
plt.title('Fruit Sales')
plt.xlabel('Fruits')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # Bar Plot in Matplotlib

# %%
import numpy as np 
import  matplotlib.pyplot as plt 

fruits=["Apples","Bananas","Cherries","Dates"]
sales=[400,350,160,320]
plt.bar(fruits,sales)
plt.title("Fruits Sales")
plt.xlabel("Fruits")
plt.ylabel("Sales")
plt.show()
